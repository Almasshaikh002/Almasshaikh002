# %% [markdown]
# <a href="https://colab.research.google.com/github/Almasshaikh002/Almasshaikh002/blob/main/almas_project_cb002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA #ML lib PCA is in this library
from sklearn.preprocessing import StandardScaler # standarsding data
import matplotlib.pyplot as plt # plotting visulization

# %%
#url= "https://archive.ics.uci.edu/ml/machine-learning-databases/penguins/penguins.data"
#df=pd.read_csv(url,names=['Species', "Culmen Length (mm)", "Culmen Length (mm)","Flipper Length (mm)", "Body Mass (g)", "Sex"])

# %%
df=pd.read_csv("penguins.csv")

# %%
df
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
features = ['Species', "Culmen Length (mm)", "Culmen Length (mm)","Flipper Length (mm)", "Body Mass (g)", "Sex"] # x values
x = df.drop(columns='Species',axis=1)
y = df["Species"]

# %%
x
# Out:
#     studyName  Sample Number  Region     Island               Stage  \
# 0     PAL0708              1  Anvers  Torgersen  Adult, 1 Egg Stage
# 1     PAL0708              2  Anvers  Torgersen  Adult, 1 Egg Stage
# 2     PAL0708              3  Anvers  Torgersen  Adult, 1 Egg Stage
# 3     PAL0708              4  Anvers  Torgersen  Adult, 1 Egg Stage
# 4     PAL0708              5  Anvers  Torgersen  Adult, 1 Egg Stage
# ..        ...            ...     ...        ...                 ...
# 339   PAL0910            120  Anvers     Biscoe  Adult, 1 Egg Stage
# 340   PAL0910            121  Anvers     Biscoe  Adult, 1 Egg Stage
# 341   PAL0910            122  Anvers     Biscoe  Adult, 1 Egg Stage
# 342   PAL0910            123  Anvers     Biscoe  Adult, 1 Egg Stage
# 343   PAL0910            124  Anvers     Biscoe  Adult, 1 Egg Stage
#
#     Individual ID Clutch Completion  Date Egg  Culmen Length (mm)  \
# 0            N1A1               Yes  11/11/07                39.1
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
df2 = pd.DataFrame(data = x, columns=features)
df2.head()
# Out:
#    Species  Culmen Length (mm)  Culmen Length (mm)  Flipper Length (mm)  \
# 0      NaN                39.1                39.1                181.0
# 1      NaN                39.5                39.5                186.0
# 2      NaN                40.3                40.3                195.0
# 3      NaN                 NaN                 NaN                  NaN
# 4      NaN                36.7                36.7                193.0
#
#    Body Mass (g)     Sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE

# %%
df.corr()
# Out:
#                      Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# Sample Number             1.000000           -0.236356          -0.022352
# Culmen Length (mm)       -0.236356            1.000000          -0.235053
# Culmen Depth (mm)        -0.022352           -0.235053           1.000000
# Flipper Length (mm)       0.040849            0.656181          -0.583851
# Body Mass (g)            -0.007042            0.595110          -0.471916
# Delta 15 N (o/oo)         0.006952           -0.059759           0.605874
# Delta 13 C (o/oo)        -0.488690            0.189025           0.429933
#
#                      Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# Sample Number                   0.040849      -0.007042           0.006952
# Culmen Length (mm)              0.656181       0.595110          -0.059759
# Culmen Depth (mm)              -0.583851      -0.471916           0.605874
# ...

# %%
dataset = pd.read_csv("penguins.csv")
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
plt.subplot(121)
plt.scatter(x[:,0], x[:,1])
plt.xlabel('x1')
plt.ylabel('y1')
# Out:
# Text(0, 0.5, 'y1')

# %%
pip install factor_analyzer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 375 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 199 kB 9.3 MB/s
# ...
#      |████████████████████████████████| 98 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 8.8 MB 49.8 MB/s
# ...
#      |████████████████████████████████| 468 kB 50.6 MB/s
# ...
#   Created wheel for factor-analyzer: filename=factor_analyzer-0.4.1-py2.py3-none-any.whl size=42034 sha256=020ba3a059aaa7bdc5e700f93d35be486c4dd0abc27cc36e88d9b168a9d9f082
#   Stored in directory: /root/.cache/pip/wheels/f5/8f/2e/a689c21bc4bf04f84ceebf4b1f5846cacc04bfe179e7ad5ab0
# Successfully built factor-analyzer
# ...

# %%
import pandas as pd
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("penguins.csv")
df.columns
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'],
#       dtype='object')

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value,p_value=calculate_bartlett_sphericity(df)
chi_square_value, p_value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-e9b0b8738dc1> in <module>
#       1 from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
# ----> 2 chi_square_value,p_value=calculate_bartlett_sphericity(df)
#       3 chi_square_value, p_value
#
# /usr/local/lib/python3.8/dist-packages/factor_analyzer/factor_analyzer.py in calculate_bartlett_sphericity(x)
#     103     """
#     104     n, p = x.shape
# --> 105     x_corr = corr(x)
#     106
#     107     corr_det = np.linalg.det(x_corr)
#
# /usr/local/lib/python3.8/dist-packages/factor_analyzer/utils.py in corr(x)
#      89     """
#      90     x = (x - np.mean(x, axis=0)) / np.std(x, axis=0, ddof=0)
# ---> 91     r = cov(x)
#      92     return r
#      93
#
# /usr/local/lib/python3.8/dist-packages/factor_analyzer/utils.py in cov(x, ddof)
# ...
